# %%
import pandas as pd
df = pd.read_csv('./2022-01-21_output.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                      time  mAAPL  mABNB  mAMD  mAMZN  mARKK  mBABA  mBTC  \
# 0     2022-01-21 09:13:10   0.08   4.27  4.53   3.22   7.94   4.01  5.94
# 1     2022-01-21 09:13:41   0.08   4.27  4.53   3.22   7.94   4.01  5.94
# 2     2022-01-21 09:14:11   0.92   4.27  4.53   3.22   7.94   4.01  5.94
# 3     2022-01-21 09:14:42   0.92   4.42  4.45   3.20   7.94   4.09  5.71
# 4     2022-01-21 09:15:12   0.91   4.42  4.43   3.14   7.94   4.07  5.72
# ...                   ...    ...    ...   ...    ...    ...    ...   ...
# 3184  2022-01-22 15:05:02  -0.65   3.92  2.44   1.76   7.30   4.37  5.76
# 3185  2022-01-22 15:05:33  -0.65   3.92  2.44   1.76   7.30   4.37  5.76
# 3186  2022-01-22 15:06:04  -0.65   3.92  2.44   1.76   7.30   4.37  5.67
# 3187  2022-01-22 15:06:34  -0.65   3.92  2.44   1.76   7.30   4.37  5.60
# 3188  2022-01-22 15:07:05  -0.65   3.92  2.44   1.76   7.30   4.37  5.60
#
# ...

# %%
df.head()
# Out:
#                   time  mAAPL  mABNB  mAMD  mAMZN  mARKK  mBABA  mBTC  mCOIN  \
# 0  2022-01-21 09:13:10   0.08   4.27  4.53   3.22   7.94   4.01  5.94   6.51
# 1  2022-01-21 09:13:41   0.08   4.27  4.53   3.22   7.94   4.01  5.94   6.51
# 2  2022-01-21 09:14:11   0.92   4.27  4.53   3.22   7.94   4.01  5.94   6.22
# 3  2022-01-21 09:14:42   0.92   4.42  4.45   3.20   7.94   4.09  5.71   6.22
# 4  2022-01-21 09:15:12   0.91   4.42  4.43   3.14   7.94   4.07  5.72   6.48
#
#     mDOT  ...  mPYPL  mQQQ  mSBUX  mSLV  mSPY   mSQ  mTSLA  mTWTR  mUSO  mVIXY
# 0  10.12  ...   4.64  3.74   4.27  4.87  2.16  7.30   2.00   8.98  3.35   2.02
# 1  10.12  ...   4.64  3.74   4.27  4.87  2.16  7.30   2.00   8.98  3.35   2.02
# 2  10.12  ...   4.64  3.74   4.27  4.87  2.16  7.30   2.00   8.98  3.35   2.02
# 3   9.83  ...   4.49  3.71   4.29  4.87  2.12  7.30   1.99   8.98  3.33   2.02
# 4   9.76  ...   4.83  3.72   4.18  4.87  2.12  7.28   1.99   8.98  3.33   2.16
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['time', 'mAAPL', 'mABNB', 'mAMD', 'mAMZN', 'mARKK', 'mBABA', 'mBTC',
#        'mCOIN', 'mDOT', 'mETH', 'mFB', 'mGLXY', 'mGOOGL', 'mGS', 'mHOOD',
#        'mIAU', 'mJNJ', 'mKO', 'mMSFT', 'mNFLX', 'mNIO', 'mNVDA', 'mPYPL',
#        'mQQQ', 'mSBUX', 'mSLV', 'mSPY', 'mSQ', 'mTSLA', 'mTWTR', 'mUSO',
#        'mVIXY'],
#       dtype='object')

# %%
df['mAAPL'].plot()
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#        time  mAAPL  mABNB   mAMD  mAMZN  mARKK  mBABA   mBTC  mCOIN   mDOT  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 3184  False  False  False  False  False  False  False  False  False  False
# 3185  False  False  False  False  False  False  False  False  False  False
# 3186  False  False  False  False  False  False  False  False  False  False
# 3187  False  False  False  False  False  False  False  False  False  False
# 3188  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# time      0
# mAAPL     7
# mABNB     7
# mAMD      7
# mAMZN     7
# mARKK     7
# mBABA     7
# mBTC      7
# mCOIN     7
# mDOT      7
# mETH      7
# mFB       7
# mGLXY     7
# mGOOGL    7
# mGS       7
# mHOOD     7
# mIAU      7
# mJNJ      7
# mKO       7
# mMSFT     7
# mNFLX     7
# mNIO      7
# mNVDA     7
# mPYPL     7
# mQQQ      7
# mSBUX     7
# mSLV      7
# mSPY      7
# mSQ       7
# mTSLA     7
# mTWTR     7
# mUSO      7
# mVIXY     7
# dtype: int64

# %%
new_df = df.dropna()

# %%
data = new_df

# %%
data.describe()
# Out:
#              mAAPL        mABNB         mAMD        mAMZN        mARKK  \
# count  3182.000000  3182.000000  3182.000000  3182.000000  3182.000000
# mean     -0.054934     3.785292     2.435132     1.929359     6.717131
# std       4.710237     4.548078     4.593037     4.559687     4.725079
# min    -100.000000  -100.000000  -100.000000  -100.000000  -100.000000
# 25%      -0.050000     3.790000     1.790000     1.080000     6.290000
# 50%       0.120000     3.960000     2.325000     1.900000     7.160000
# 75%       0.420000     4.090000     3.740000     2.840000     7.457500
# max       1.130000     7.010000     4.840000     4.730000    10.380000
#
#              mBABA         mBTC        mCOIN         mDOT         mETH  ...  \
# count  3182.000000  3182.000000  3182.000000  3182.000000  3182.000000  ...
# mean      4.689934     4.648696     7.218334     6.727090     3.963878  ...
# std       4.989005     5.403473     5.178466     5.211132     4.576597  ...
# ...

# %%
for col in data.columns[1:]:
    data = data.drop(index=data[data[col]==-100].index)

# %%
data.columns
# Out:
# Index(['time', 'mAAPL', 'mABNB', 'mAMD', 'mAMZN', 'mARKK', 'mBABA', 'mBTC',
#        'mCOIN', 'mDOT', 'mETH', 'mFB', 'mGLXY', 'mGOOGL', 'mGS', 'mHOOD',
#        'mIAU', 'mJNJ', 'mKO', 'mMSFT', 'mNFLX', 'mNIO', 'mNVDA', 'mPYPL',
#        'mQQQ', 'mSBUX', 'mSLV', 'mSPY', 'mSQ', 'mTSLA', 'mTWTR', 'mUSO',
#        'mVIXY'],
#       dtype='object')

# %%
data
# Out:
#                      time  mAAPL  mABNB  mAMD  mAMZN  mARKK  mBABA  mBTC  \
# 0     2022-01-21 09:13:10   0.08   4.27  4.53   3.22   7.94   4.01  5.94
# 1     2022-01-21 09:13:41   0.08   4.27  4.53   3.22   7.94   4.01  5.94
# 2     2022-01-21 09:14:11   0.92   4.27  4.53   3.22   7.94   4.01  5.94
# 3     2022-01-21 09:14:42   0.92   4.42  4.45   3.20   7.94   4.09  5.71
# 4     2022-01-21 09:15:12   0.91   4.42  4.43   3.14   7.94   4.07  5.72
# ...                   ...    ...    ...   ...    ...    ...    ...   ...
# 3184  2022-01-22 15:05:02  -0.65   3.92  2.44   1.76   7.30   4.37  5.76
# 3185  2022-01-22 15:05:33  -0.65   3.92  2.44   1.76   7.30   4.37  5.76
# 3186  2022-01-22 15:06:04  -0.65   3.92  2.44   1.76   7.30   4.37  5.67
# 3187  2022-01-22 15:06:34  -0.65   3.92  2.44   1.76   7.30   4.37  5.60
# 3188  2022-01-22 15:07:05  -0.65   3.92  2.44   1.76   7.30   4.37  5.60
#
#       mCOIN   mDOT  ...  mPYPL  mQQQ  mSBUX  mSLV  mSPY   mSQ  mTSLA  mTWTR  \
# ...

# %%
data.describe()
# Out:
#              mAAPL        mABNB         mAMD        mAMZN        mARKK  \
# count  3169.000000  3169.000000  3169.000000  3169.000000  3169.000000
# mean      0.164841     3.981253     2.628536     2.122086     6.917804
# std       0.395767     0.575310     1.126100     1.077113     0.898052
# min      -0.650000    -3.020000    -0.030000    -0.070000     4.540000
# 25%      -0.050000     3.790000     1.790000     1.080000     6.290000
# 50%       0.120000     3.960000     2.330000     1.910000     7.160000
# 75%       0.420000     4.090000     3.740000     2.840000     7.450000
# max       1.130000     7.010000     4.840000     4.730000    10.380000
#
#              mBABA         mBTC        mCOIN         mDOT         mETH  ...  \
# count  3169.000000  3169.000000  3169.000000  3169.000000  3169.000000  ...
# mean      4.921445     4.911925     7.456444     6.960442     4.159820  ...
# std       0.849390     1.261361     1.211047     1.428052     0.721897  ...
# ...

# %%
data['time'] = pd.to_datetime(data['time'], format="%Y-%m-%d %H:%M:%S")

# %%
data['Hour'] = data['time'].dt.hour
hour = data.groupby('Hour').mean().reset_index()

# %%
hour
# Out:
#     Hour     mAAPL     mABNB      mAMD     mAMZN     mARKK     mBABA  \
# 0      0  0.584466  5.173010  1.827184  1.457184  7.742427  5.971359
# 1      1  0.473982  4.025841  1.767522  1.579646  5.902920  5.800177
# 2      2  0.477699  4.082478  2.477699  2.549027  6.491947  6.224248
# 3      3  0.124554  4.359018  2.381786  2.627589  6.660893  6.452946
# 4      4  0.117586  4.451724  2.847500  2.959483  6.688276  6.467845
# 5      5  0.116379  4.446810  3.741379  4.033793  6.560086  6.157328
# 6      6 -0.037248  3.049633  3.920550  4.579174  6.728257  6.060642
# 7      7  0.085391  3.401130  4.071913  3.813826  7.061043  5.404609
# 8      8  0.286410  3.872051  4.376581  2.697436  7.075385  4.138034
# 9      9  0.645174  4.083383  4.440000  2.972338  7.533831  4.427264
# 10    10  0.604823  4.001195  3.823363  2.861327  7.590000  4.683805
# 11    11  0.481518  4.003795  3.012946  2.705536  7.595268  4.637098
# 12    12  0.237366  3.995402  2.305893  1.865312  7.597366  4.512634
# ...

# %%
import matplotlib.pyplot as plt

# %%
# fig, axes = plt.subplots(4, 1, figsize=(8, 20))
# axes[0].bar(hour['Hour'], hour['Users'], color='r')
# axes[1].bar(hour['Hour'], hour['Sessions'], color='g')
# axes[2].bar(hour['Hour'], hour['NewVisitors'], color='b')
# axes[3].bar(hour['Hour'], hour['PageViews'], color='c')
fig, axes = plt.subplots(len(list(data.columns)[1:]), 1, figsize=(8, 300))
for i, title in enumerate(list(data.columns)[1:]):
    axes[i].set_title(title)
    axes[i].bar(hour['Hour'], hour[title])
plt.show()
